# %%
# %env PATH=/usr/local/cuda-11.5/bin:$PATH
# Out:
# env: PATH=/usr/local/cuda-11.5/bin:$PATH

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

# %%
from pinns.prelude import *
from pinns.model import mlp
from pinns.domain import Sphere
from pinns.calc import laplace, divergence
from pinns.opt import run_epoch
from scipy.stats.qmc import Sobol
import matplotlib.pyplot as plt

# %%
domain = Sphere(1., (0., 0., 0.))
x_dom = array(Sobol(3, seed=0).random_base2(10))
x_dom = domain.transform(x_dom)
x_bnd = array(Sobol(2, seed=1).random_base2(8))
x_bnd = domain.transform_bnd(x_bnd)


@jit
def make_batches(rng, phi=None):
    batches = 24
    k1, k2 = random.split(rng)
    batch_size_dom = x_dom.shape[0] // batches
    batch_size_bnd = x_bnd.shape[0] // batches

    perms_dom = jax.random.permutation(k1, x_dom.shape[0])
    perms_dom = perms_dom[:batches * batch_size_dom]  # skip incomplete batch
    perms_dom = perms_dom.reshape((batches, batch_size_dom))

    perms_bnd = jax.random.permutation(k2, x_bnd.shape[0])
    perms_bnd = perms_bnd[:batches * batch_size_bnd]  # skip incomplete batch
    perms_bnd = perms_bnd.reshape((batches, batch_size_bnd))

    if phi is None:
        return x_dom[perms_dom, :], x_bnd[perms_bnd, :]
    else:
        return x_dom[perms_dom, :], x_bnd[perms_bnd, :], phi[perms_bnd]
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
key, subkey = random.split(random.PRNGKey(42), 2)
phi1, params = mlp(subkey, [3, 15, 15, 15,  1])
tx = optax.adam(0.001)
init_state1 = TrainState.create(
    apply_fn=phi1.apply, 
    params=params['params'],
    tx=tx
)

def mag(x):
    return x / norm(x)# array([0., 0., 1.])


def loss1(params, x_dom, x_bnd):
    _pde_loss = lambda x, _, p: (-laplace(phi1)(x, p) + divergence(mag)(x)) ** 2
    _bnd_loss = lambda _, x, p: (phi1.apply(p, x)) ** 2

    pde_loss = mean(vmap(_pde_loss, (0, None, None))(x_dom, x_bnd, params))
    bnd_loss = mean(vmap(_bnd_loss, (None, 0, None))(x_dom, x_bnd, params))
    _loss = pde_loss + bnd_loss
    return _loss, {'pde_loss': pde_loss, 'bnd_loss': bnd_loss, 'loss': _loss}

# %%
state1 = init_state1
for epoch in range(0, 4000):
    key, subkey = random.split(key)
    data = make_batches(subkey)
    state1, epoch_metrics = run_epoch(state1, loss1, data)
    if epoch % 100 == 0:
        epoch_metrics = tree_map(mean, epoch_metrics)
        print(f"train epoch: {epoch}, pde_loss: {epoch_metrics['pde_loss']:.4e}, bnd_loss: {epoch_metrics['bnd_loss']:.4e}")

params1 = {'params': state1.params}
# Out:
# train epoch: 0, pde_loss: 1.1456e+01, bnd_loss: 2.4188e-02
# train epoch: 100, pde_loss: 1.6833e-01, bnd_loss: 8.8567e-03
# train epoch: 200, pde_loss: 6.7281e-02, bnd_loss: 4.0319e-03
# train epoch: 300, pde_loss: 4.0596e-02, bnd_loss: 2.3081e-03
# train epoch: 400, pde_loss: 2.5086e-02, bnd_loss: 1.2071e-03
# train epoch: 500, pde_loss: 1.7716e-02, bnd_loss: 1.1168e-03
# train epoch: 600, pde_loss: 1.4771e-02, bnd_loss: 6.5519e-04
# train epoch: 700, pde_loss: 1.2788e-02, bnd_loss: 5.3539e-04
# train epoch: 800, pde_loss: 1.0234e-02, bnd_loss: 4.3649e-04
# train epoch: 900, pde_loss: 1.1972e-02, bnd_loss: 9.3044e-04
# train epoch: 1000, pde_loss: 8.0957e-03, bnd_loss: 4.7287e-04
# train epoch: 1100, pde_loss: 6.5356e-03, bnd_loss: 4.3844e-04
# train epoch: 1200, pde_loss: 6.3528e-03, bnd_loss: 2.6276e-04
# train epoch: 1300, pde_loss: 6.4805e-03, bnd_loss: 4.8669e-04
# train epoch: 1400, pde_loss: 7.3518e-03, bnd_loss: 7.6651e-04
# train epoch: 1500, pde_loss: 6.7513e-03, bnd_loss: 3.6394e-04
# train epoch: 1600, pde_loss: 4.7895e-03, bnd_loss: 2.7373e-04
# train epoch: 1700, pde_loss: 4.2163e-03, bnd_loss: 2.6057e-04
# train epoch: 1800, pde_loss: 8.1667e-03, bnd_loss: 3.5737e-04
# train epoch: 1900, pde_loss: 5.9921e-03, bnd_loss: 4.7990e-04
# train epoch: 2000, pde_loss: 3.7768e-03, bnd_loss: 2.4474e-04
# train epoch: 2100, pde_loss: 3.1258e-03, bnd_loss: 2.2106e-04
# train epoch: 2200, pde_loss: 2.6690e-03, bnd_loss: 2.2469e-04
# train epoch: 2300, pde_loss: 2.1968e-03, bnd_loss: 1.4964e-04
# train epoch: 2400, pde_loss: 2.5813e-03, bnd_loss: 2.0725e-04
# train epoch: 2500, pde_loss: 2.4329e-03, bnd_loss: 1.4156e-04
# train epoch: 2600, pde_loss: 2.0307e-03, bnd_loss: 1.5605e-04
# train epoch: 2700, pde_loss: 1.8849e-03, bnd_loss: 1.3575e-04
# train epoch: 2800, pde_loss: 2.1875e-03, bnd_loss: 1.6571e-04
# train epoch: 2900, pde_loss: 3.2625e-03, bnd_loss: 2.5694e-04
# train epoch: 3000, pde_loss: 1.7416e-03, bnd_loss: 1.3757e-04
# train epoch: 3100, pde_loss: 1.8630e-03, bnd_loss: 1.4582e-04
# train epoch: 3200, pde_loss: 2.2492e-03, bnd_loss: 1.6599e-04
# train epoch: 3300, pde_loss: 3.8050e-03, bnd_loss: 3.2495e-04
# train epoch: 3400, pde_loss: 1.9548e-03, bnd_loss: 1.4403e-04
# train epoch: 3500, pde_loss: 1.3106e-03, bnd_loss: 9.6938e-05
# train epoch: 3600, pde_loss: 2.9387e-03, bnd_loss: 1.5486e-04
# train epoch: 3700, pde_loss: 4.0967e-03, bnd_loss: 2.7758e-04
# train epoch: 3800, pde_loss: 2.6840e-03, bnd_loss: 1.5327e-04
# train epoch: 3900, pde_loss: 3.7192e-03, bnd_loss: 1.7106e-04

# %%
def phi2_solution(x, x_bnd):
    eps = 1e-7
    def g(y):
        n = y / norm(y, axis=-1)
        return dot(mag(y), n) - dot(grad(phi1.apply, 1)(params1, y), n)
    
    dist = vmap(lambda x: norm(x - x_bnd, axis=-1))(x)
    _g = vmap(g)(x_bnd)
    def kernel(dist):
        idx = dist > eps
        newton_kernel = where(idx, 1 / dist, 0.)
        N = jnp.count_nonzero(idx)
        return (4 * pi * 1. ** 2) / (4 * pi * N) * dot(newton_kernel, _g)

    return vmap(kernel)(dist)

# %%
_x_bnd = array(Sobol(2, seed=123).random_base2(15))
_x_bnd = domain.transform_bnd(_x_bnd)
phi_bnd = phi2_solution(x_bnd, _x_bnd)

# %%
key, subkey = random.split(key, 2)
phi2, params2 = mlp(subkey, [3, 40, 40, 1])

tx = optax.adam(0.001)
init_state2 = TrainState.create(
    apply_fn=phi2.apply, 
    params=params2['params'],
    tx=tx
)

def loss2(params, x_dom, x_bnd, y_bnd):
    _pde_loss = lambda x, _, y, p: (laplace(phi2)(x, p)) ** 2
    _bnd_loss = lambda _, x, y, p: (phi2.apply(p, x) - y) ** 2

    pde_loss = mean(vmap(_pde_loss, (0, None, None, None))(x_dom, x_bnd, y_bnd, params))
    bnd_loss = mean(vmap(_bnd_loss, (None, 0, 0, None))(x_dom, x_bnd, y_bnd, params))
    _loss = pde_loss + bnd_loss
    return _loss, {'pde_loss': pde_loss, 'bnd_loss': bnd_loss, 'loss': _loss}

# %%
state2 = init_state2
for epoch in range(0, 5000):
    key, subkey = random.split(key)
    data = make_batches(subkey, phi_bnd)
    state2, epoch_metrics = run_epoch(state2, loss2, data)
    if epoch % 100 == 0:
        epoch_metrics = tree_map(mean, epoch_metrics)
        print(f"train epoch: {epoch}, pde_loss: {epoch_metrics['pde_loss']:.4e}, bnd_loss: {epoch_metrics['bnd_loss']:.4e}")

params2 = {'params': state2.params}
# Out:
# train epoch: 0, pde_loss: 5.8513e-02, bnd_loss: 1.6213e-02
# train epoch: 100, pde_loss: 3.7404e-05, bnd_loss: 2.3860e-05
# train epoch: 200, pde_loss: 1.8141e-05, bnd_loss: 1.9847e-05
# train epoch: 300, pde_loss: 1.9855e-05, bnd_loss: 2.6141e-05
# train epoch: 400, pde_loss: 4.0534e-05, bnd_loss: 3.4893e-05
# train epoch: 500, pde_loss: 1.1887e-05, bnd_loss: 2.2361e-05
# train epoch: 600, pde_loss: 7.5199e-06, bnd_loss: 1.9405e-05
# train epoch: 700, pde_loss: 5.2609e-06, bnd_loss: 1.6069e-05
# train epoch: 800, pde_loss: 1.2699e-05, bnd_loss: 3.4688e-05
# train epoch: 900, pde_loss: 4.4455e-06, bnd_loss: 1.8913e-05
# train epoch: 1000, pde_loss: 5.6766e-06, bnd_loss: 1.9605e-05
# train epoch: 1100, pde_loss: 2.1337e-06, bnd_loss: 1.5632e-05
# train epoch: 1200, pde_loss: 1.5474e-06, bnd_loss: 1.5726e-05
# train epoch: 1300, pde_loss: 1.3391e-06, bnd_loss: 1.6849e-05
# train epoch: 1400, pde_loss: 5.8586e-07, bnd_loss: 1.6340e-05
# train epoch: 1500, pde_loss: 6.3762e-07, bnd_loss: 1.7495e-05
# train epoch: 1600, pde_loss: 7.9165e-07, bnd_loss: 1.6347e-05
# train epoch: 1700, pde_loss: 4.2800e-07, bnd_loss: 1.4531e-05
# train epoch: 1800, pde_loss: 4.2366e-07, bnd_loss: 1.5405e-05
# train epoch: 1900, pde_loss: 3.7870e-07, bnd_loss: 1.4243e-05
# train epoch: 2000, pde_loss: 7.6965e-07, bnd_loss: 1.7136e-05
# train epoch: 2100, pde_loss: 5.3627e-07, bnd_loss: 1.3438e-05
# train epoch: 2200, pde_loss: 3.4916e-07, bnd_loss: 1.4123e-05
# train epoch: 2300, pde_loss: 4.5606e-07, bnd_loss: 1.4310e-05
# train epoch: 2400, pde_loss: 2.9045e-07, bnd_loss: 1.5406e-05
# train epoch: 2500, pde_loss: 4.6122e-07, bnd_loss: 1.4248e-05
# train epoch: 2600, pde_loss: 7.1972e-07, bnd_loss: 1.5018e-05
# train epoch: 2700, pde_loss: 2.9668e-07, bnd_loss: 1.3866e-05
# train epoch: 2800, pde_loss: 4.2207e-07, bnd_loss: 1.4926e-05
# train epoch: 2900, pde_loss: 3.9116e-07, bnd_loss: 1.4053e-05
# train epoch: 3000, pde_loss: 3.9711e-07, bnd_loss: 1.3993e-05
# train epoch: 3100, pde_loss: 5.6637e-07, bnd_loss: 1.5062e-05
# train epoch: 3200, pde_loss: 3.6833e-07, bnd_loss: 1.3700e-05
# train epoch: 3300, pde_loss: 5.7744e-07, bnd_loss: 1.5342e-05
# train epoch: 3400, pde_loss: 6.5357e-07, bnd_loss: 1.5111e-05
# train epoch: 3500, pde_loss: 5.1895e-07, bnd_loss: 1.6742e-05
# train epoch: 3600, pde_loss: 5.0022e-07, bnd_loss: 1.3542e-05
# train epoch: 3700, pde_loss: 5.8310e-07, bnd_loss: 1.4521e-05
# train epoch: 3800, pde_loss: 4.8127e-07, bnd_loss: 1.3267e-05
# train epoch: 3900, pde_loss: 4.1621e-07, bnd_loss: 1.3223e-05
# train epoch: 4000, pde_loss: 5.4660e-07, bnd_loss: 1.5928e-05
# train epoch: 4100, pde_loss: 6.0085e-07, bnd_loss: 1.3774e-05
# train epoch: 4200, pde_loss: 6.5314e-07, bnd_loss: 1.3071e-05
# train epoch: 4300, pde_loss: 7.6994e-07, bnd_loss: 1.2348e-05
# train epoch: 4400, pde_loss: 5.3297e-07, bnd_loss: 1.3307e-05
# train epoch: 4500, pde_loss: 4.8017e-07, bnd_loss: 1.3269e-05
# train epoch: 4600, pde_loss: 9.3430e-07, bnd_loss: 1.3892e-05
# train epoch: 4700, pde_loss: 7.9114e-07, bnd_loss: 1.3158e-05
# train epoch: 4800, pde_loss: 7.2177e-07, bnd_loss: 1.3625e-05
# train epoch: 4900, pde_loss: 1.3912e-06, bnd_loss: 1.4712e-05

# %%
def nn_solution(x):
    return phi1.apply(params1, x) + phi2.apply(params2, x)


phi_nn = lambda x: phi1.apply(params1, x) + phi2.apply(params2, x)
y_analytic = lambda x: norm(x, axis=-1) - 1# x_dom[:, 2] / 3
mean((y_analytic(x_dom) - phi_nn(x_dom)) ** 2)
# Out:
# DeviceArray(0.00130472, dtype=float32)

# %%
import itertools
import numpy as np

def plot_sol(sol, ax):
    plt.sca(ax)
    N = 1000
    x = np.linspace(-1, 1, N)
    z = np.linspace(-1, 1, N)
    X = np.array([_x for _x in itertools.product(x, z)])
    _X = jnp.asarray(X)
    _X = jnp.insert(_X, array([1]), zeros((N * N, 1)), 1)
    phi = np.array(sol(_X))
    phi[np.linalg.norm(X, axis=-1) > 1.] = np.nan

    p = ax.contourf(x, z, phi.reshape(N, N).T, 20, cmap=plt.get_cmap("autumn"), alpha=0.5)
    plt.colorbar(p)

fig = plt.figure(figsize=(8, 3))
ax1, ax2 = fig.subplots(1, 2)
plt.subplots_adjust(wspace=0.4)
ax1.set_title("PINN")
plot_sol(phi_nn, ax1)
ax2.set_title("Squared error")
plot_sol(lambda x: abs(y_analytic(x) -  phi_nn(x)), ax2)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
p = ax.scatter(x_bnd[:, 0], x_bnd[:, 1], x_bnd[:, 2], c=phi_bnd[:])
plt.colorbar(p)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
