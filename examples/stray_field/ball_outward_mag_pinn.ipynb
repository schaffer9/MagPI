# %%
# %env PATH=/usr/local/cuda-11.5/bin:$PATH
# Out:
# env: PATH=/usr/local/cuda-11.5/bin:$PATH

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

# %%
from pinns.prelude import *
from pinns.model import mlp
from pinns.domain import Sphere
from pinns.calc import laplace, divergence
from pinns.opt import run_epoch
from scipy.stats.qmc import Sobol
import matplotlib.pyplot as plt

# %%
domain = Sphere(1., (0., 0., 0.))
x_dom = array(Sobol(3, seed=0).random_base2(10))
x_dom = domain.transform(x_dom)
x_bnd = array(Sobol(2, seed=1).random_base2(8))
x_bnd = domain.transform_bnd(x_bnd)


@jit
def make_batches(rng, phi=None):
    batches = 24
    k1, k2 = random.split(rng)
    batch_size_dom = x_dom.shape[0] // batches
    batch_size_bnd = x_bnd.shape[0] // batches

    perms_dom = jax.random.permutation(k1, x_dom.shape[0])
    perms_dom = perms_dom[:batches * batch_size_dom]  # skip incomplete batch
    perms_dom = perms_dom.reshape((batches, batch_size_dom))

    perms_bnd = jax.random.permutation(k2, x_bnd.shape[0])
    perms_bnd = perms_bnd[:batches * batch_size_bnd]  # skip incomplete batch
    perms_bnd = perms_bnd.reshape((batches, batch_size_bnd))

    if phi is None:
        return x_dom[perms_dom, :], x_bnd[perms_bnd, :]
    else:
        return x_dom[perms_dom, :], x_bnd[perms_bnd, :], phi[perms_bnd]

# %%
key, subkey = random.split(random.PRNGKey(42), 2)
phi1, params = mlp(subkey, [3, 20, 20, 20,  1])
tx = optax.adam(0.001)
init_state1 = TrainState.create(
    apply_fn=phi1.apply, 
    params=params,
    tx=tx
)

def mag(x):
    return x / norm(x)# array([0., 0., 1.])


def loss1(params, x_dom, x_bnd):
    _pde_loss = lambda x, _, p: (-laplace(phi1)(x, p) + divergence(mag)(x)) ** 2
    _bnd_loss = lambda _, x, p: (phi1.apply(p, x)) ** 2

    pde_loss = mean(vmap(_pde_loss, (0, None, None))(x_dom, x_bnd, params))
    bnd_loss = mean(vmap(_bnd_loss, (None, 0, None))(x_dom, x_bnd, params))
    _loss = pde_loss + bnd_loss
    return _loss, {'pde_loss': pde_loss, 'bnd_loss': bnd_loss, 'loss': _loss}

# %%
state1 = init_state1
for epoch in range(0, 4000):
    key, subkey = random.split(key)
    data = make_batches(subkey)
    state1, epoch_metrics = run_epoch(state1, loss1, data)
    if epoch % 100 == 0:
        epoch_metrics = tree_map(mean, epoch_metrics)
        print(f"train epoch: {epoch}, pde_loss: {epoch_metrics['pde_loss']:.4e}, bnd_loss: {epoch_metrics['bnd_loss']:.4e}")

params1 = state1.params
# Out:
# train epoch: 0, pde_loss: 1.1504e+01, bnd_loss: 4.6250e-02
# train epoch: 100, pde_loss: 1.3972e-01, bnd_loss: 9.9624e-03
# train epoch: 200, pde_loss: 5.9795e-02, bnd_loss: 2.7208e-03
# train epoch: 300, pde_loss: 4.0832e-02, bnd_loss: 1.8742e-03
# train epoch: 400, pde_loss: 2.5796e-02, bnd_loss: 1.0129e-03
# train epoch: 500, pde_loss: 1.7289e-02, bnd_loss: 6.1868e-04
# train epoch: 600, pde_loss: 1.4082e-02, bnd_loss: 3.7982e-04
# train epoch: 700, pde_loss: 1.4112e-02, bnd_loss: 1.3839e-03
# train epoch: 800, pde_loss: 6.4029e-03, bnd_loss: 3.1093e-04
# train epoch: 900, pde_loss: 9.4409e-03, bnd_loss: 5.3654e-04
# train epoch: 1000, pde_loss: 4.7363e-03, bnd_loss: 2.3917e-04
# train epoch: 1100, pde_loss: 5.5299e-03, bnd_loss: 2.9519e-04
# train epoch: 1200, pde_loss: 4.0089e-03, bnd_loss: 2.6026e-04
# train epoch: 1300, pde_loss: 5.9255e-03, bnd_loss: 2.6595e-04
# train epoch: 1400, pde_loss: 3.2008e-03, bnd_loss: 3.0336e-04
# train epoch: 1500, pde_loss: 3.5404e-03, bnd_loss: 1.9936e-04
# train epoch: 1600, pde_loss: 7.6524e-03, bnd_loss: 5.9429e-04
# train epoch: 1700, pde_loss: 9.7178e-03, bnd_loss: 3.7417e-04
# train epoch: 1800, pde_loss: 2.2488e-03, bnd_loss: 1.4953e-04
# train epoch: 1900, pde_loss: 2.4101e-03, bnd_loss: 1.8131e-04
# train epoch: 2000, pde_loss: 2.3692e-03, bnd_loss: 1.3927e-04
# train epoch: 2100, pde_loss: 2.2316e-03, bnd_loss: 1.2900e-04
# train epoch: 2200, pde_loss: 1.9556e-03, bnd_loss: 1.2617e-04
# train epoch: 2300, pde_loss: 1.6834e-03, bnd_loss: 1.3514e-04
# train epoch: 2400, pde_loss: 4.8266e-03, bnd_loss: 3.2863e-04
# train epoch: 2500, pde_loss: 1.6663e-03, bnd_loss: 9.4847e-05
# train epoch: 2600, pde_loss: 7.1040e-03, bnd_loss: 3.3269e-04
# train epoch: 2700, pde_loss: 1.2305e-03, bnd_loss: 7.9988e-05
# train epoch: 2800, pde_loss: 3.1138e-03, bnd_loss: 1.6311e-04
# train epoch: 2900, pde_loss: 6.9605e-03, bnd_loss: 4.3983e-04
# train epoch: 3000, pde_loss: 3.4038e-03, bnd_loss: 2.0947e-04
# train epoch: 3100, pde_loss: 9.4089e-04, bnd_loss: 6.4864e-05
# train epoch: 3200, pde_loss: 4.1864e-03, bnd_loss: 1.7012e-04
# train epoch: 3300, pde_loss: 9.5818e-04, bnd_loss: 6.1597e-05
# train epoch: 3400, pde_loss: 2.0132e-03, bnd_loss: 8.6920e-05
# train epoch: 3500, pde_loss: 1.2479e-03, bnd_loss: 7.4444e-05
# train epoch: 3600, pde_loss: 1.5230e-03, bnd_loss: 9.5511e-05
# train epoch: 3700, pde_loss: 1.2754e-02, bnd_loss: 4.7473e-04
# train epoch: 3800, pde_loss: 6.0580e-03, bnd_loss: 2.4639e-04
# train epoch: 3900, pde_loss: 2.8850e-03, bnd_loss: 1.6287e-04

# %%
def phi2_solution(x, x_bnd):
    eps = 1e-7
    def g(y):
        n = y / norm(y, axis=-1)
        return dot(mag(y), n) - dot(grad(phi1.apply, 1)(params1, y), n)
    
    dist = vmap(lambda x: norm(x - x_bnd, axis=-1))(x)
    _g = vmap(g)(x_bnd)
    def kernel(dist):
        idx = dist > eps
        newton_kernel = where(idx, 1 / dist, 0.)
        N = jnp.count_nonzero(idx)
        return (4 * pi * 1. ** 2) / (4 * pi * N) * dot(newton_kernel, _g)

    return vmap(kernel)(dist)

# %%
_x_bnd = array(Sobol(2, seed=123).random_base2(15))
_x_bnd = domain.transform_bnd(_x_bnd)
phi_bnd = phi2_solution(x_bnd, _x_bnd)

# %%
key, subkey = random.split(key, 2)
phi2, params2 = mlp(subkey, [3, 40, 40, 1])

tx = optax.adam(0.001)
init_state2 = TrainState.create(
    apply_fn=phi2.apply, 
    params=params2,
    tx=tx
)

def loss2(params, x_dom, x_bnd, y_bnd):
    _pde_loss = lambda x, _, y, p: (laplace(phi2)(x, p)) ** 2
    _bnd_loss = lambda _, x, y, p: (phi2.apply(p, x) - y) ** 2

    pde_loss = mean(vmap(_pde_loss, (0, None, None, None))(x_dom, x_bnd, y_bnd, params))
    bnd_loss = mean(vmap(_bnd_loss, (None, 0, 0, None))(x_dom, x_bnd, y_bnd, params))
    _loss = pde_loss + bnd_loss
    return _loss, {'pde_loss': pde_loss, 'bnd_loss': bnd_loss, 'loss': _loss}

# %%
state2 = init_state2
for epoch in range(0, 5000):
    key, subkey = random.split(key)
    data = make_batches(subkey, phi_bnd)
    state2, epoch_metrics = run_epoch(state2, loss2, data)
    if epoch % 100 == 0:
        epoch_metrics = tree_map(mean, epoch_metrics)
        print(f"train epoch: {epoch}, pde_loss: {epoch_metrics['pde_loss']:.4e}, bnd_loss: {epoch_metrics['bnd_loss']:.4e}")

params2 = state2.params
# Out:
# train epoch: 0, pde_loss: 5.8452e-02, bnd_loss: 1.6463e-02
# train epoch: 100, pde_loss: 3.2845e-05, bnd_loss: 1.8090e-05
# train epoch: 200, pde_loss: 1.6656e-05, bnd_loss: 1.8070e-05
# train epoch: 300, pde_loss: 1.3055e-05, bnd_loss: 1.4762e-05
# train epoch: 400, pde_loss: 1.3930e-05, bnd_loss: 1.5391e-05
# train epoch: 500, pde_loss: 1.0317e-05, bnd_loss: 1.5077e-05
# train epoch: 600, pde_loss: 1.7055e-05, bnd_loss: 1.9756e-05
# train epoch: 700, pde_loss: 5.1051e-06, bnd_loss: 1.5374e-05
# train epoch: 800, pde_loss: 5.3643e-06, bnd_loss: 1.3148e-05
# train epoch: 900, pde_loss: 2.0846e-06, bnd_loss: 1.1245e-05
# train epoch: 1000, pde_loss: 2.3830e-06, bnd_loss: 1.1743e-05
# train epoch: 1100, pde_loss: 8.5730e-07, bnd_loss: 1.0460e-05
# train epoch: 1200, pde_loss: 1.1618e-06, bnd_loss: 1.0380e-05
# train epoch: 1300, pde_loss: 2.2079e-07, bnd_loss: 9.0957e-06
# train epoch: 1400, pde_loss: 1.9536e-07, bnd_loss: 9.2259e-06
# train epoch: 1500, pde_loss: 1.6274e-07, bnd_loss: 9.6097e-06
# train epoch: 1600, pde_loss: 1.5244e-07, bnd_loss: 9.6394e-06
# train epoch: 1700, pde_loss: 6.5910e-08, bnd_loss: 9.0004e-06
# train epoch: 1800, pde_loss: 7.6630e-08, bnd_loss: 1.0083e-05
# train epoch: 1900, pde_loss: 7.3484e-08, bnd_loss: 9.6336e-06
# train epoch: 2000, pde_loss: 1.7376e-07, bnd_loss: 1.0292e-05
# train epoch: 2100, pde_loss: 9.8622e-08, bnd_loss: 1.0319e-05
# train epoch: 2200, pde_loss: 8.9847e-08, bnd_loss: 1.0085e-05
# train epoch: 2300, pde_loss: 7.2079e-08, bnd_loss: 9.3041e-06
# train epoch: 2400, pde_loss: 8.8966e-08, bnd_loss: 9.7165e-06
# train epoch: 2500, pde_loss: 8.4843e-08, bnd_loss: 9.5647e-06
# train epoch: 2600, pde_loss: 7.4498e-08, bnd_loss: 9.9182e-06
# train epoch: 2700, pde_loss: 6.8194e-08, bnd_loss: 9.3685e-06
# train epoch: 2800, pde_loss: 1.0339e-07, bnd_loss: 9.7711e-06
# train epoch: 2900, pde_loss: 7.2611e-08, bnd_loss: 1.0975e-05
# train epoch: 3000, pde_loss: 7.9217e-08, bnd_loss: 9.0295e-06
# train epoch: 3100, pde_loss: 5.2186e-08, bnd_loss: 9.0479e-06
# train epoch: 3200, pde_loss: 6.5426e-08, bnd_loss: 9.6941e-06
# train epoch: 3300, pde_loss: 1.0511e-07, bnd_loss: 9.9628e-06
# train epoch: 3400, pde_loss: 5.7596e-08, bnd_loss: 1.0414e-05
# train epoch: 3500, pde_loss: 1.0098e-07, bnd_loss: 9.6988e-06
# train epoch: 3600, pde_loss: 5.0956e-08, bnd_loss: 9.2659e-06
# train epoch: 3700, pde_loss: 6.0196e-08, bnd_loss: 9.5156e-06
# train epoch: 3800, pde_loss: 1.0340e-07, bnd_loss: 9.0500e-06
# train epoch: 3900, pde_loss: 6.8342e-08, bnd_loss: 9.4816e-06
# train epoch: 4000, pde_loss: 5.9834e-08, bnd_loss: 1.0019e-05
# train epoch: 4100, pde_loss: 7.8247e-08, bnd_loss: 9.4254e-06
# train epoch: 4200, pde_loss: 4.8833e-08, bnd_loss: 9.0065e-06
# train epoch: 4300, pde_loss: 5.1718e-08, bnd_loss: 9.4912e-06
# train epoch: 4400, pde_loss: 5.4219e-08, bnd_loss: 9.2931e-06
# train epoch: 4500, pde_loss: 5.3449e-08, bnd_loss: 9.2035e-06
# train epoch: 4600, pde_loss: 5.8442e-08, bnd_loss: 9.6274e-06
# train epoch: 4700, pde_loss: 6.3075e-08, bnd_loss: 9.3589e-06
# train epoch: 4800, pde_loss: 5.8416e-08, bnd_loss: 1.0505e-05
# train epoch: 4900, pde_loss: 5.6091e-08, bnd_loss: 1.0676e-05

# %%
def nn_solution(x):
    return phi1.apply(params1, x) + phi2.apply(params2, x)


phi_nn = lambda x: phi1.apply(params1, x) + phi2.apply(params2, x)
y_analytic = lambda x: norm(x, axis=-1) - 1# x_dom[:, 2] / 3
mean(abs(y_analytic(x_dom) - phi_nn(x_dom)))
# Out:
# DeviceArray(0.0042649, dtype=float32)

# %%
import itertools
import numpy as np

def plot_sol(sol, ax):
    plt.sca(ax)
    N = 1000
    x = np.linspace(-1, 1, N)
    z = np.linspace(-1, 1, N)
    X = np.array([_x for _x in itertools.product(x, z)])
    _X = jnp.asarray(X)
    _X = jnp.insert(_X, array([1]), zeros((N * N, 1)), 1)
    phi = np.array(sol(_X))
    phi[np.linalg.norm(X, axis=-1) > 1.] = np.nan

    p = ax.contourf(x, z, phi.reshape(N, N).T, 20, cmap=plt.get_cmap("autumn"), alpha=0.5)
    plt.colorbar(p)

fig = plt.figure(figsize=(8, 3))
ax1, ax2 = fig.subplots(1, 2)
plt.subplots_adjust(wspace=0.4)
ax1.set_title("PINN")
plot_sol(phi_nn, ax1)
ax2.set_title("Absolute Error")
plot_sol(lambda x: abs(y_analytic(x) -  phi_nn(x)), ax2)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
p = ax.scatter(x_bnd[:, 0], x_bnd[:, 1], x_bnd[:, 2], c=phi_bnd[:])
plt.colorbar(p)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
